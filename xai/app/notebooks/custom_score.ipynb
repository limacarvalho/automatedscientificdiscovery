# %%
import numpy as np
import matplotlib.pyplot as plt

# %%
train = np.array(np.arange(0.05, 1.1, 0.1))
test = train

# %%
avg_score = train * test / (train + test)

# %%
avg_score
# Out:
# array([0.025, 0.075, 0.125, 0.175, 0.225, 0.275, 0.325, 0.375, 0.425,
#        0.475, 0.525])

# %%
# create x,y
xx, yy = np.meshgrid(np.arange(0.05, 1.1, 0.1), np.arange(0.05, 1.1, 0.1))

# %%
# calculate corresponding z
diff = np.sqrt(abs(xx - yy))
z = xx * yy / (xx + yy)

# %%
# z

# %%
# %matplotlib widget
# %matplotlib notebook
# Out:
# Warning: Cannot change to a different GUI toolkit: notebook. Using widget instead.

# %%
from mpl_toolkits import mplot3d
import numpy as np
import matplotlib.pyplot as plt
  
fig = plt.figure(figsize = (8,8))
ax = plt.axes(projection = '3d')
  
# Plot the surface.
from matplotlib import cm

surf = ax.plot_surface(xx, yy, z, cmap=cm.coolwarm,
                       linewidth=0, antialiased=False)
  

# Customize the z axis.
ax.set_zlim(0, 0.6)

ax.view_init(-140, 60)
# Out:
# Canvas(toolbar=Toolbar(toolitems=[('Home', 'Reset original view', 'home', 'home'), ('Back', 'Back to previous …
