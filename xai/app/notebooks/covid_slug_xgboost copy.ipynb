# %%
# %load_ext autoreload
# %autoreload 2

# %%
import sys; sys.path.insert(0, '..') # add parent folder path where lib folder is

# %%
from ml.preprocess import data
from utils import helper
from ml.models.base.slug_xgboost import SlugXGBoost
from sklearn.model_selection import train_test_split

from sklearn.metrics import r2_score, mean_squared_error
from sklearn.metrics import f1_score, roc_auc_score, precision_score, recall_score

# %%
X, y = helper.get_covid_dataset()

X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.33)

# %%
# X, y

# %%
slug_xgboost = SlugXGBoost()
slug_xgboost.X_train = X_train
slug_xgboost.X_test = X_test
slug_xgboost.y_train = y_train
slug_xgboost.y_test = y_test

slug_xgboost.n_trails = 2000    #### increase this number to imporve the goodness of fit

# %%
best_xgboost = slug_xgboost.fetch_model()
# Out:
# Dask dashboard is available at http://127.0.0.1:8787/status
# Starting train for trials:2000 with boosted rounds:250
# Cleared previous models in the model save path
# 2022-10-12 13:39:34,600 - distributed.utils_perf - WARNING - full garbage collections took 10% CPU time recently (threshold: 10%)
# 2022-10-12 13:39:41,077 - distributed.utils_perf - WARNING - full garbage collections took 10% CPU time recently (threshold: 10%)
# 2022-10-12 13:39:41,817 - distributed.utils_perf - WARNING - full garbage collections took 10% CPU time recently (threshold: 10%)
# 2022-10-12 13:39:44,301 - distributed.utils_perf - WARNING - full garbage collections took 10% CPU time recently (threshold: 10%)
# 2022-10-12 13:39:47,764 - distributed.utils_perf - WARNING - full garbage collections took 10% CPU time recently (threshold: 10%)
# 2022-10-12 13:39:49,398 - distributed.utils_perf - WARNING - full garbage collections took 10% CPU time recently (threshold: 10%)
# ...

# %%
# use any of the score functions of sklearn.metircs, pass a list
slug_xgboost.get_model_score(score_func=[r2_score, mean_squared_error])
# Out:
# [0.5464848737241019, 427048.8419057452]
