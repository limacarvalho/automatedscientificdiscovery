# %%
import sys; sys.path.insert(0, '../..') # add parent folder path where lib folder is

# %%
# %load_ext autoreload
# %autoreload 2

from utils import helper, config, rayer, kaggle_dataset_helper

from sklearn.preprocessing import StandardScaler
from sklearn.model_selection import train_test_split

import xgboost as xgb
from sklearn.ensemble import BaggingClassifier, BaggingRegressor

from sklearn.metrics import r2_score, mean_squared_error
from sklearn.metrics import f1_score, roc_auc_score, precision_score, recall_score
from ml.models import common
import ray
import time
import pandas as pd
# Out:
# <style type='text/css'>
# .datatable table.frame { margin-bottom: 0; }
# .datatable table.frame thead { border-bottom: none; }
# .datatable table.frame tr.coltypes td {  color: #FFFFFF;  line-height: 6px;  padding: 0 0.5em;}
# .datatable .bool    { background: #DDDD99; }
# .datatable .object  { background: #565656; }
# .datatable .int     { background: #5D9E5D; }
# .datatable .float   { background: #4040CC; }
# .datatable .str     { background: #CC4040; }
# .datatable .time    { background: #40CC40; }
# .datatable .row_index {  background: var(--jp-border-color3);  border-right: 1px solid var(--jp-border-color0);  color: var(--jp-ui-font-color3);  font-size: 9px;}
# .datatable .frame tbody td { text-align: left; }
# .datatable .frame tr.coltypes .row_index {  background: var(--jp-border-color0);}
# .datatable th:nth-child(2) { padding-left: 12px; }
# .datatable .hellipsis {  color: var(--jp-cell-editor-border-color);}
# .datatable .vellipsis {  background: var(--jp-layout-color0);  color: var(--jp-cell-editor-border-color);}
# .datatable .na {  color: var(--jp-cell-editor-border-color);  font-size: 80%;}
# .datatable .sp {  opacity: 0.25;}
# .datatable .footer { font-size: 9px; }
# .datatable .frame_dimensions {  background: var(--jp-border-color3);  border-top: 1px solid var(--jp-border-color0);  color: var(--jp-ui-font-color3);  display: inline-block;  opacity: 0.6;  padding: 1px 10px 1px 5px;}
# .datatable .frame thead tr.colnames {  background-image: url('data:image/png;base64,...');  background-repeat: repeat-x;  background-size: 14px;  height: 28px;}
# </style>

# %%
from ray import tune, air
# from ray.tune.search.optuna import OptunaSearch
from ray.tune.search.bayesopt import BayesOptSearch

# %%
rayer.get_global_cluster()
# Out:
# 2022-12-02 15:29:20,024	INFO packaging.py:527 -- Creating a file package for local directory '/mnt/c/Users/rwmas/GitHub/xai/python-asd/xai/'.
# 2022-12-02 15:29:55,941	INFO packaging.py:354 -- Pushing file package 'gcs://_ray_pkg_4abdf7a932e7a6c9.zip' (30.53MiB) to Ray cluster...
# 2022-12-02 15:29:57,458	INFO packaging.py:367 -- Successfully pushed file package 'gcs://_ray_pkg_4abdf7a932e7a6c9.zip'.

# %%
ds_train, ds_test = kaggle_dataset_helper.get_transaction_predictions_dataset()
ds_train = common.label_encode(ds_train)
ds_test = common.label_encode(ds_test)

ds_train = ds_train.fillna(-1)
ds_test = ds_test.fillna(-1)

df_X = ds_train.loc[:, ds_train.columns != 'target']
df_y = ds_train['target']

X_train, X_test, y_train, y_test = train_test_split(df_X, df_y, test_size=0.33, random_state=config.rand_state)


ss = StandardScaler()
X_train_scalar = pd.DataFrame(ss.fit_transform(X_train), columns = X_train.columns)
X_test_scalar = pd.DataFrame(ss.fit_transform(X_test), columns = X_test.columns)

# %%
X, y = helper.get_covid_dataset()
X = X.drop(['location'], axis = 1)

X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.33)

ss = StandardScaler()
X_train_scalar = pd.DataFrame(ss.fit_transform(X_train), columns = X_train.columns)
X_test_scalar = pd.DataFrame(ss.fit_transform(X_test), columns = X_test.columns)

# %%
# y_train = y_train.values.reshape(y_train.shape[0], -1)
# y_test = y_test.values.reshape(y_test.shape[0], -1)

# %%
X_train_id = ray.put(X_train_scalar)
y_train_id = ray.put(y_train)
X_test_id = ray.put(X_test_scalar)
y_test_id = ray.put(y_test)

# %%
def __objective__(params, X_train_ref, X_test_ref, y_train_ref, y_test_ref, pred_class):

    # criterion = “gini” [“gini”, “entropy”, “log_loss”]

    X_train = ray.get(X_train_ref)
    X_test = ray.get(X_test_ref)
    y_train = ray.get(y_train_ref)
    y_test = ray.get(y_test_ref)

    # print(X_train.head())
    n_estimators = int(params['n_estimators'])

    if pred_class == 'regression':
        # cv = KFold(n_splits=self.cv_splits, shuffle=True, random_state=config.rand_state)
        score_func = mean_squared_error
        model = BaggingRegressor(n_estimators=n_estimators)

    else:
        # cv = StratifiedKFold(n_splits=self.cv_splits, shuffle=True, random_state=config.rand_state)
        score_func = f1_score
        model =  BaggingClassifier(n_estimators=n_estimators)


    model.fit(X_train, y_train.values.ravel())

    pred_train = model.predict(X_train)
    pred_test = model.predict(X_test)

    err_test = score_func(y_test, pred_test)
    err_train = score_func(y_train, pred_train)
        
    #metirc_score_train, metirc_score_test, weighted_score = self.__get_model_score__(pred_train, pred_test, y_train, y_test, self.score_func)
    weighted_score = common.get_weighted_score(err_train, err_test, pred_class, score_func)

    tune.report(weighted_score=weighted_score)

# %%
n_estimators = 10
n_trials = 10

baye_space = {
    # 'base_estimator': DecisionTreeRegressor
    'n_estimators': (10, n_estimators),
}

xgb_space = {
        "objective": 'count:poisson',
        "booster": (["gbtree", "dart"]),
#        "lambda": trial.suggest_float("lambda", 1e-3, 1.0, log=True),
#        "alpha": trial.suggest_float("alpha", 1e-3, 1.0, log=True),
    }


obj_func = lambda params: __objective__(params, X_train_id, X_test_id, y_train_id, y_test_id, 'regression')

# algo = OptunaSearch(space=params, metric="mean_loss", mode="min")
bayesopt = BayesOptSearch(space=baye_space, metric="weighted_score", mode="min",  random_state=config.rand_state)
# algo = ConcurrencyLimiter(algo, max_concurrent=4)

tuner = tune.Tuner(
    obj_func,
    run_config=air.RunConfig(
      name=config.create_study_name(),
      #stop={"training_iteration": 1 if args.smoke_test else 10},
    ),
    tune_config=tune.TuneConfig(
        search_alg=bayesopt,
        num_samples=n_trials,
        #checkpoint_dir=None,
    ),
#            param_space=params,
)
# Out:
# ---------------------------------------------------------------------------
# AssertionError                            Traceback (most recent call last)
# /mnt/c/Users/rwmas/GitHub/xai/python-asd/xai/notebooks/RayBayesOpt/test_ray_bayeshypopt_bagging.ipynb Cell 10 in <cell line: 20>()
#      <a href='vscode-notebook-cell://wsl%2Bubuntu/mnt/c/Users/rwmas/GitHub/xai/python-asd/xai/notebooks/RayBayesOpt/test_ray_bayeshypopt_bagging.ipynb#X15sdnNjb2RlLXJlbW90ZQ%3D%3D?line=16'>17</a> obj_func = lambda params: __objective__(params, X_train_id, X_test_id, y_train_id, y_test_id, 'regression')
#      <a href='vscode-notebook-cell://wsl%2Bubuntu/mnt/c/Users/rwmas/GitHub/xai/python-asd/xai/notebooks/RayBayesOpt/test_ray_bayeshypopt_bagging.ipynb#X15sdnNjb2RlLXJlbW90ZQ%3D%3D?line=18'>19</a> # algo = OptunaSearch(space=params, metric="mean_loss", mode="min")
# ---> <a href='vscode-notebook-cell://wsl%2Bubuntu/mnt/c/Users/rwmas/GitHub/xai/python-asd/xai/notebooks/RayBayesOpt/test_ray_bayeshypopt_bagging.ipynb#X15sdnNjb2RlLXJlbW90ZQ%3D%3D?line=19'>20</a> bayesopt = BayesOptSearch(space=baye_space, metric="weighted_score", mode="min",  random_state=config.rand_state)
#      <a href='vscode-notebook-cell://wsl%2Bubuntu/mnt/c/Users/rwmas/GitHub/xai/python-asd/xai/notebooks/RayBayesOpt/test_ray_bayeshypopt_bagging.ipynb#X15sdnNjb2RlLXJlbW90ZQ%3D%3D?line=20'>21</a> # algo = ConcurrencyLimiter(algo, max_concurrent=4)
#      <a href='vscode-notebook-cell://wsl%2Bubuntu/mnt/c/Users/rwmas/GitHub/xai/python-asd/xai/notebooks/RayBayesOpt/test_ray_bayeshypopt_bagging.ipynb#X15sdnNjb2RlLXJlbW90ZQ%3D%3D?line=22'>23</a> tuner = tune.Tuner(
#      <a href='vscode-notebook-cell://wsl%2Bubuntu/mnt/c/Users/rwmas/GitHub/xai/python-asd/xai/notebooks/RayBayesOpt/test_ray_bayeshypopt_bagging.ipynb#X15sdnNjb2RlLXJlbW90ZQ%3D%3D?line=23'>24</a>     obj_func,
#      <a href='vscode-notebook-cell://wsl%2Bubuntu/mnt/c/Users/rwmas/GitHub/xai/python-asd/xai/notebooks/RayBayesOpt/test_ray_bayeshypopt_bagging.ipynb#X15sdnNjb2RlLXJlbW90ZQ%3D%3D?line=24'>25</a>     run_config=air.RunConfig(
#    (...)
#      <a href='vscode-notebook-cell://wsl%2Bubuntu/mnt/c/Users/rwmas/GitHub/xai/python-asd/xai/notebooks/RayBayesOpt/test_ray_bayeshypopt_bagging.ipynb#X15sdnNjb2RlLXJlbW90ZQ%3D%3D?line=33'>34</a> #            param_space=params,
#      <a href='vscode-notebook-cell://wsl%2Bubuntu/mnt/c/Users/rwmas/GitHub/xai/python-asd/xai/notebooks/RayBayesOpt/test_ray_bayeshypopt_bagging.ipynb#X15sdnNjb2RlLXJlbW90ZQ%3D%3D?line=34'>35</a> )
#
# File ~/miniconda3/envs/automl/lib/python3.8/site-packages/ray/tune/search/bayesopt/bayesopt_search.py:147, in BayesOptSearch.__init__(self, space, metric, mode, points_to_evaluate, utility_kwargs, random_state, random_search_steps, verbose, patience, skip_duplicate, analysis)
#     133 def __init__(
#     134     self,
#     135     space: Optional[Dict] = None,
#    (...)
#     145     analysis: Optional["ExperimentAnalysis"] = None,
#     146 ):
# --> 147     assert byo is not None, (
#     148         "BayesOpt must be installed!. You can install BayesOpt with"
#     149         " the command: `pip install bayesian-optimization`."
#     150     )
#     151     if mode:
#     152         assert mode in ["min", "max"], "`mode` must be 'min' or 'max'."
#
# AssertionError: BayesOpt must be installed!. You can install BayesOpt with the command: `pip install bayesian-optimization`.

# %%
results = tuner.fit()
best_result = results.get_best_result()

print('############################')
print("Best hyperparameters: ", best_result)
print("Best hyperparameters: ", best_result.config)

# %%
xgb_space = {
        # "objective": 'count:poisson',
        #"booster": ("gbtree", "dart"),
        "lambda": (1e-3, 1.0),
#        "alpha": trial.suggest_float("alpha", 1e-3, 1.0, log=True),
    }


obj_func = lambda params: __objective_xgb__(params, X_train_id, X_test_id, y_train_id, y_test_id, 'regression')

# algo = OptunaSearch(space=params, metric="mean_loss", mode="min")
bayesopt = BayesOptSearch(space=xgb_space, metric="weighted_score", mode="min",  random_state=config.rand_state)
# algo = ConcurrencyLimiter(algo, max_concurrent=4)

tuner = tune.Tuner(
    obj_func,
    run_config=air.RunConfig(
      name=config.create_study_name(),
      #stop={"training_iteration": 1 if args.smoke_test else 10},
    ),
    tune_config=tune.TuneConfig(
        search_alg=bayesopt,
        num_samples=n_trials,
        #checkpoint_dir=None,
    ),
#            param_space=params,
)

results = tuner.fit()
best_result = results.get_best_result()

print('############################')
print("Best hyperparameters: ", best_result)
print("Best hyperparameters: ", best_result.config)
# Out:
# <div class="tuneStatus">
#   <div style="display: flex;flex-direction: row">
#     <div style="display: flex;flex-direction: column;">
#       <h3>Tune Status</h3>
#       <table>
# <tbody>
# <tr><td>Current time:</td><td>
Error processing event.
# ray.exceptions.RayTaskError(NameError): ray::ImplicitFunc.train() (pid=25385, ip=10.10.100.184, repr=<lambda>)
#   File "/home/conda/admin/807c952d1ebb2e498414dc4b80a90b96c80ef2ef433f07c7a7381b5e38e2b5fa-20221110-224801-275852-64-wasif-dev-ray/lib/python3.9/site-packages/ray/tune/trainable/trainable.py", line 355, in train
#     raise skipped from exception_cause(skipped)
#   File "/home/conda/admin/807c952d1ebb2e498414dc4b80a90b96c80ef2ef433f07c7a7381b5e38e2b5fa-20221110-224801-275852-64-wasif-dev-ray/lib/python3.9/site-packages/ray/tune/trainable/function_trainable.py", line 325, in entrypoint
#     return self._trainable_func(
#   File "/home/conda/admin/807c952d1ebb2e498414dc4b80a90b96c80ef2ef433f07c7a7381b5e38e2b5fa-20221110-224801-275852-64-wasif-dev-ray/lib/python3.9/site-packages/ray/tune/trainable/function_trainable.py", line 651, in _trainable_func
#     output = fn()
#   File "/tmp/ipykernel_23266/969626250.py", line 9, in <lambda>
#   File "/tmp/ipykernel_23266/2380396921.py", line 13, in __objective_xgb__
# NameError: name 'param' is not defined
# 2022-11-24 12:36:25,051	ERROR trial_runner.py:993 -- Trial lambda_e4419180: Error processing event.
# ray.exceptions.RayTaskError(NameError): ray::ImplicitFunc.train() (pid=25396, ip=10.10.100.184, repr=<lambda>)
#   File "/home/conda/admin/807c952d1ebb2e498414dc4b80a90b96c80ef2ef433f07c7a7381b5e38e2b5fa-20221110-224801-275852-64-wasif-dev-ray/lib/python3.9/site-packages/ray/tune/trainable/trainable.py", line 355, in train
#     raise skipped from exception_cause(skipped)
#   File "/home/conda/admin/807c952d1ebb2e498414dc4b80a90b96c80ef2ef433f07c7a7381b5e38e2b5fa-20221110-224801-275852-64-wasif-dev-ray/lib/python3.9/site-packages/ray/tune/trainable/function_trainable.py", line 325, in entrypoint
#     return self._trainable_func(
#   File "/home/conda/admin/807c952d1ebb2e498414dc4b80a90b96c80ef2ef433f07c7a7381b5e38e2b5fa-20221110-224801-275852-64-wasif-dev-ray/lib/python3.9/site-packages/ray/tune/trainable/function_trainable.py", line 651, in _trainable_func
#     output = fn()
#   File "/tmp/ipykernel_23266/969626250.py", line 9, in <lambda>
#   File "/tmp/ipykernel_23266/2380396921.py", line 13, in __objective_xgb__
# NameError: name 'param' is not defined
# 2022-11-24 12:36:30,713	ERROR trial_runner.py:993 -- Trial lambda_e7af0712: Error processing event.
# ray.exceptions.RayTaskError(NameError): ray::ImplicitFunc.train() (pid=25535, ip=10.10.100.184, repr=<lambda>)
#   File "/home/conda/admin/807c952d1ebb2e498414dc4b80a90b96c80ef2ef433f07c7a7381b5e38e2b5fa-20221110-224801-275852-64-wasif-dev-ray/lib/python3.9/site-packages/ray/tune/trainable/trainable.py", line 355, in train
#     raise skipped from exception_cause(skipped)
#   File "/home/conda/admin/807c952d1ebb2e498414dc4b80a90b96c80ef2ef433f07c7a7381b5e38e2b5fa-20221110-224801-275852-64-wasif-dev-ray/lib/python3.9/site-packages/ray/tune/trainable/function_trainable.py", line 325, in entrypoint
#     return self._trainable_func(
#   File "/home/conda/admin/807c952d1ebb2e498414dc4b80a90b96c80ef2ef433f07c7a7381b5e38e2b5fa-20221110-224801-275852-64-wasif-dev-ray/lib/python3.9/site-packages/ray/tune/trainable/function_trainable.py", line 651, in _trainable_func
#     output = fn()
#   File "/tmp/ipykernel_23266/969626250.py", line 9, in <lambda>
#   File "/tmp/ipykernel_23266/2380396921.py", line 13, in __objective_xgb__
# NameError: name 'param' is not defined
# 2022-11-24 12:36:30,797	ERROR trial_runner.py:993 -- Trial lambda_e4d4e502: Error processing event.
# ray.exceptions.RayTaskError(NameError): ray::ImplicitFunc.train() (pid=25529, ip=10.10.100.184, repr=<lambda>)
#   File "/home/conda/admin/807c952d1ebb2e498414dc4b80a90b96c80ef2ef433f07c7a7381b5e38e2b5fa-20221110-224801-275852-64-wasif-dev-ray/lib/python3.9/site-packages/ray/tune/trainable/trainable.py", line 355, in train
#     raise skipped from exception_cause(skipped)
#   File "/home/conda/admin/807c952d1ebb2e498414dc4b80a90b96c80ef2ef433f07c7a7381b5e38e2b5fa-20221110-224801-275852-64-wasif-dev-ray/lib/python3.9/site-packages/ray/tune/trainable/function_trainable.py", line 325, in entrypoint
#     return self._trainable_func(
#   File "/home/conda/admin/807c952d1ebb2e498414dc4b80a90b96c80ef2ef433f07c7a7381b5e38e2b5fa-20221110-224801-275852-64-wasif-dev-ray/lib/python3.9/site-packages/ray/tune/trainable/function_trainable.py", line 651, in _trainable_func
#     output = fn()
#   File "/tmp/ipykernel_23266/969626250.py", line 9, in <lambda>
#   File "/tmp/ipykernel_23266/2380396921.py", line 13, in __objective_xgb__
# NameError: name 'param' is not defined
# 2022-11-24 12:36:30,824	ERROR trial_runner.py:993 -- Trial lambda_e7b63fe6: Error processing event.
# ray.exceptions.RayTaskError(NameError): ray::ImplicitFunc.train() (pid=25537, ip=10.10.100.184, repr=<lambda>)
#   File "/home/conda/admin/807c952d1ebb2e498414dc4b80a90b96c80ef2ef433f07c7a7381b5e38e2b5fa-20221110-224801-275852-64-wasif-dev-ray/lib/python3.9/site-packages/ray/tune/trainable/trainable.py", line 355, in train
#     raise skipped from exception_cause(skipped)
#   File "/home/conda/admin/807c952d1ebb2e498414dc4b80a90b96c80ef2ef433f07c7a7381b5e38e2b5fa-20221110-224801-275852-64-wasif-dev-ray/lib/python3.9/site-packages/ray/tune/trainable/function_trainable.py", line 325, in entrypoint
#     return self._trainable_func(
#   File "/home/conda/admin/807c952d1ebb2e498414dc4b80a90b96c80ef2ef433f07c7a7381b5e38e2b5fa-20221110-224801-275852-64-wasif-dev-ray/lib/python3.9/site-packages/ray/tune/trainable/function_trainable.py", line 651, in _trainable_func
#     output = fn()
#   File "/tmp/ipykernel_23266/969626250.py", line 9, in <lambda>
#   File "/tmp/ipykernel_23266/2380396921.py", line 13, in __objective_xgb__
# NameError: name 'param' is not defined
# 2022-11-24 12:36:30,855	ERROR trial_runner.py:993 -- Trial lambda_e7a7dec4: Error processing event.
# ray.exceptions.RayTaskError(NameError): ray::ImplicitFunc.train() (pid=25531, ip=10.10.100.184, repr=<lambda>)
#   File "/home/conda/admin/807c952d1ebb2e498414dc4b80a90b96c80ef2ef433f07c7a7381b5e38e2b5fa-20221110-224801-275852-64-wasif-dev-ray/lib/python3.9/site-packages/ray/tune/trainable/trainable.py", line 355, in train
#     raise skipped from exception_cause(skipped)
#   File "/home/conda/admin/807c952d1ebb2e498414dc4b80a90b96c80ef2ef433f07c7a7381b5e38e2b5fa-20221110-224801-275852-64-wasif-dev-ray/lib/python3.9/site-packages/ray/tune/trainable/function_trainable.py", line 325, in entrypoint
#     return self._trainable_func(
#   File "/home/conda/admin/807c952d1ebb2e498414dc4b80a90b96c80ef2ef433f07c7a7381b5e38e2b5fa-20221110-224801-275852-64-wasif-dev-ray/lib/python3.9/site-packages/ray/tune/trainable/function_trainable.py", line 651, in _trainable_func
#     output = fn()
#   File "/tmp/ipykernel_23266/969626250.py", line 9, in <lambda>
#   File "/tmp/ipykernel_23266/2380396921.py", line 13, in __objective_xgb__
# NameError: name 'param' is not defined
# 2022-11-24 12:36:34,992	ERROR trial_runner.py:993 -- Trial lambda_e7bdc09a: Error processing event.
# ray.exceptions.RayTaskError(NameError): ray::ImplicitFunc.train() (pid=25678, ip=10.10.100.184, repr=<lambda>)
#   File "/home/conda/admin/807c952d1ebb2e498414dc4b80a90b96c80ef2ef433f07c7a7381b5e38e2b5fa-20221110-224801-275852-64-wasif-dev-ray/lib/python3.9/site-packages/ray/tune/trainable/trainable.py", line 355, in train
#     raise skipped from exception_cause(skipped)
#   File "/home/conda/admin/807c952d1ebb2e498414dc4b80a90b96c80ef2ef433f07c7a7381b5e38e2b5fa-20221110-224801-275852-64-wasif-dev-ray/lib/python3.9/site-packages/ray/tune/trainable/function_trainable.py", line 325, in entrypoint
#     return self._trainable_func(
#   File "/home/conda/admin/807c952d1ebb2e498414dc4b80a90b96c80ef2ef433f07c7a7381b5e38e2b5fa-20221110-224801-275852-64-wasif-dev-ray/lib/python3.9/site-packages/ray/tune/trainable/function_trainable.py", line 651, in _trainable_func
#     output = fn()
#   File "/tmp/ipykernel_23266/969626250.py", line 9, in <lambda>
#   File "/tmp/ipykernel_23266/2380396921.py", line 13, in __objective_xgb__
# NameError: name 'param' is not defined
# 2022-11-24 12:36:35,168	ERROR tune.py:773 -- Trials did not complete: [lambda_e2d4d7ee, lambda_e42bd41c, lambda_e432e428, lambda_e43a1db0, lambda_e4419180, lambda_e4d4e502, lambda_e7a7dec4, lambda_e7af0712, lambda_e7b63fe6, lambda_e7bdc09a]
# 2022-11-24 12:36:35,168	INFO tune.py:777 -- Total run time: 16.33 seconds (16.17 seconds for the tuning loop).
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In [63], line 30
#      15 tuner = tune.Tuner(
#      16     obj_func,
#      17     run_config=air.RunConfig(
#    (...)
#      26 #            param_space=params,
#      27 )
#      29 results = tuner.fit()
# ---> 30 best_result = results.get_best_result()
#      32 print('############################')
#      33 print("Best hyperparameters: ", best_result)
#
# File /home/conda/admin/807c952d1ebb2e498414dc4b80a90b96c80ef2ef433f07c7a7381b5e38e2b5fa-20221110-224801-275852-64-wasif-dev-ray/lib/python3.9/site-packages/ray/tune/result_grid.py:120, in ResultGrid.get_best_result(self, metric, mode, scope, filter_nan_and_inf)
#     118     return self._trial_to_result(self._experiment_analysis.trials[0])
#     119 if not metric and not self._experiment_analysis.default_metric:
# --> 120     raise ValueError(
#     121         "No metric is provided. Either pass in a `metric` arg to "
#     122         "`get_best_result` or specify a metric in the "
#     123         "`TuneConfig` of your `Tuner`."
#     124     )
#     125 if not mode and not self._experiment_analysis.default_mode:
#     126     raise ValueError(
#     127         "No mode is provided. Either pass in a `mode` arg to "
#     128         "`get_best_result` or specify a mode in the "
#     129         "`TuneConfig` of your `Tuner`."
#     130     )
#
# ValueError: No metric is provided. Either pass in a `metric` arg to `get_best_result` or specify a metric in the `TuneConfig` of your `Tuner`.

# %%
from ray import tune

# 1. Define an objective function.
def objective(config):
    score = config["a"] ** 2 + config["b"]
    return {"score": score}


# 2. Define a search space.
search_space = {
    "a": tune.grid_search([0.001, 0.01, 0.1, 1.0]),
    "b": tune.choice([1, 2, 3]),
}

# 3. Start a Tune run and print the best result.
tuner = tune.Tuner(objective, param_space=search_space)
results = tuner.fit()
print(results.get_best_result(metric="score", mode="min").config)
# Out:
# (TunerInternal pid=363) 2022-11-24 07:25:40,942	WARNING function_trainable.py:586 -- Function checkpointing is disabled. This may result in unexpected behavior when using checkpointing features or certain schedulers. To enable, set the train function arguments to be `func(config, checkpoint_dir=None)`.
# (TunerInternal pid=363) == Status ==
# (TunerInternal pid=363) Current time: 2022-11-24 07:25:46 (running for 00:00:02.08)
# (TunerInternal pid=363) Memory usage on this node: 2.7/15.4 GiB
# (TunerInternal pid=363) Using FIFO scheduling algorithm.
# (TunerInternal pid=363) Resources requested: 1.0/5 CPUs, 0/0 GPUs, 0.0/16.76 GiB heap, 0.0/4.91 GiB objects
# (TunerInternal pid=363) Result logdir: /home/ray/ray_results/objective_2022-11-24_07-25-40
# (TunerInternal pid=363) Number of trials: 4/4 (3 PENDING, 1 RUNNING)
# (TunerInternal pid=363) +-----------------------+----------+-----------------+-------+-----+
# (TunerInternal pid=363) | Trial name            | status   | loc             |     a |   b |
# (TunerInternal pid=363) |-----------------------+----------+-----------------+-------+-----|
# (TunerInternal pid=363) | objective_414eb_00000 | RUNNING  | 10.10.20.33:398 | 0.001 |   2 |
# (TunerInternal pid=363) | objective_414eb_00001 | PENDING  |                 | 0.01  |   3 |
# (TunerInternal pid=363) | objective_414eb_00002 | PENDING  |                 | 0.1   |   1 |
# (TunerInternal pid=363) | objective_414eb_00003 | PENDING  |                 | 1     |   3 |
# (TunerInternal pid=363) +-----------------------+----------+-----------------+-------+-----+
# (TunerInternal pid=363)
# (TunerInternal pid=363)
# (TunerInternal pid=363) Result for objective_414eb_00000:
# (TunerInternal pid=363)   date: 2022-11-24_07-25-46
# (TunerInternal pid=363)   done: false
# (TunerInternal pid=363)   experiment_id: 2a92ed4aaf8a4ba38e5648576c78640e
# (TunerInternal pid=363)   hostname: raycluster-autoscaler-head-zkhfp
# (TunerInternal pid=363)   iterations_since_restore: 1
# (TunerInternal pid=363)   node_ip: 10.10.20.33
# (TunerInternal pid=363)   pid: 398
# (TunerInternal pid=363)   score: 2.000001
# (TunerInternal pid=363)   time_since_restore: 0.0001266002655029297
# (TunerInternal pid=363)   time_this_iter_s: 0.0001266002655029297
# (TunerInternal pid=363)   time_total_s: 0.0001266002655029297
# (TunerInternal pid=363)   timestamp: 1669303546
# (TunerInternal pid=363)   timesteps_since_restore: 0
# (TunerInternal pid=363)   training_iteration: 1
# (TunerInternal pid=363)   trial_id: 414eb_00000
# (TunerInternal pid=363)   warmup_time: 0.020821571350097656
# (TunerInternal pid=363)
# (TunerInternal pid=363) Result for objective_414eb_00000:
# (TunerInternal pid=363)   date: 2022-11-24_07-25-46
# (TunerInternal pid=363)   done: true
# (TunerInternal pid=363)   experiment_id: 2a92ed4aaf8a4ba38e5648576c78640e
# (TunerInternal pid=363)   experiment_tag: 0_a=0.0010,b=2
# (TunerInternal pid=363)   hostname: raycluster-autoscaler-head-zkhfp
# (TunerInternal pid=363)   iterations_since_restore: 1
# (TunerInternal pid=363)   node_ip: 10.10.20.33
# (TunerInternal pid=363)   pid: 398
# (TunerInternal pid=363)   score: 2.000001
# (TunerInternal pid=363)   time_since_restore: 0.0001266002655029297
# (TunerInternal pid=363)   time_this_iter_s: 0.0001266002655029297
# (TunerInternal pid=363)   time_total_s: 0.0001266002655029297
# (TunerInternal pid=363)   timestamp: 1669303546
# (TunerInternal pid=363)   timesteps_since_restore: 0
# (TunerInternal pid=363)   training_iteration: 1
# (TunerInternal pid=363)   trial_id: 414eb_00000
# (TunerInternal pid=363)   warmup_time: 0.020821571350097656
# (TunerInternal pid=363)
# (TunerInternal pid=363) Result for objective_414eb_00001:
# (TunerInternal pid=363)   date: 2022-11-24_07-25-46
# (TunerInternal pid=363)   done: false
# (TunerInternal pid=363)   experiment_id: 2a92ed4aaf8a4ba38e5648576c78640e
# (TunerInternal pid=363)   hostname: raycluster-autoscaler-head-zkhfp
# (TunerInternal pid=363)   iterations_since_restore: 1
# (TunerInternal pid=363)   node_ip: 10.10.20.33
# (TunerInternal pid=363)   pid: 398
# (TunerInternal pid=363)   score: 3.0001
# (TunerInternal pid=363)   time_since_restore: 9.083747863769531e-05
# (TunerInternal pid=363)   time_this_iter_s: 9.083747863769531e-05
# (TunerInternal pid=363)   time_total_s: 9.083747863769531e-05
# (TunerInternal pid=363)   timestamp: 1669303546
# (TunerInternal pid=363)   timesteps_since_restore: 0
# (TunerInternal pid=363)   training_iteration: 1
# (TunerInternal pid=363)   trial_id: 414eb_00001
# (TunerInternal pid=363)   warmup_time: 0.020821571350097656
# (TunerInternal pid=363)
# (TunerInternal pid=363) Result for objective_414eb_00001:
# (TunerInternal pid=363)   date: 2022-11-24_07-25-46
# (TunerInternal pid=363)   done: true
# (TunerInternal pid=363)   experiment_id: 2a92ed4aaf8a4ba38e5648576c78640e
# (TunerInternal pid=363)   experiment_tag: 1_a=0.0100,b=3
# (TunerInternal pid=363)   hostname: raycluster-autoscaler-head-zkhfp
# (TunerInternal pid=363)   iterations_since_restore: 1
# (TunerInternal pid=363)   node_ip: 10.10.20.33
# (TunerInternal pid=363)   pid: 398
# (TunerInternal pid=363)   score: 3.0001
# (TunerInternal pid=363)   time_since_restore: 9.083747863769531e-05
# (TunerInternal pid=363)   time_this_iter_s: 9.083747863769531e-05
# (TunerInternal pid=363)   time_total_s: 9.083747863769531e-05
# (TunerInternal pid=363)   timestamp: 1669303546
# (TunerInternal pid=363)   timesteps_since_restore: 0
# (TunerInternal pid=363)   training_iteration: 1
# (TunerInternal pid=363)   trial_id: 414eb_00001
# (TunerInternal pid=363)   warmup_time: 0.020821571350097656
# (TunerInternal pid=363)
# (TunerInternal pid=363) Result for objective_414eb_00002:
# (TunerInternal pid=363)   date: 2022-11-24_07-25-46
# (TunerInternal pid=363)   done: false
# (TunerInternal pid=363)   experiment_id: 2a92ed4aaf8a4ba38e5648576c78640e
# (TunerInternal pid=363)   hostname: raycluster-autoscaler-head-zkhfp
# (TunerInternal pid=363)   iterations_since_restore: 1
# (TunerInternal pid=363)   node_ip: 10.10.20.33
# (TunerInternal pid=363)   pid: 398
# (TunerInternal pid=363)   score: 1.01
# (TunerInternal pid=363)   time_since_restore: 7.295608520507812e-05
# (TunerInternal pid=363)   time_this_iter_s: 7.295608520507812e-05
# (TunerInternal pid=363)   time_total_s: 7.295608520507812e-05
# (TunerInternal pid=363)   timestamp: 1669303546
# (TunerInternal pid=363)   timesteps_since_restore: 0
# (TunerInternal pid=363)   training_iteration: 1
# (TunerInternal pid=363)   trial_id: 414eb_00002
# (TunerInternal pid=363)   warmup_time: 0.020821571350097656
# (TunerInternal pid=363)
# (TunerInternal pid=363) Result for objective_414eb_00002:
# (TunerInternal pid=363)   date: 2022-11-24_07-25-46
# (TunerInternal pid=363)   done: true
# (TunerInternal pid=363)   experiment_id: 2a92ed4aaf8a4ba38e5648576c78640e
# (TunerInternal pid=363)   experiment_tag: 2_a=0.1000,b=1
# (TunerInternal pid=363)   hostname: raycluster-autoscaler-head-zkhfp
# (TunerInternal pid=363)   iterations_since_restore: 1
# (TunerInternal pid=363)   node_ip: 10.10.20.33
# (TunerInternal pid=363)   pid: 398
# (TunerInternal pid=363)   score: 1.01
# (TunerInternal pid=363)   time_since_restore: 7.295608520507812e-05
# (TunerInternal pid=363)   time_this_iter_s: 7.295608520507812e-05
# (TunerInternal pid=363)   time_total_s: 7.295608520507812e-05
# (TunerInternal pid=363)   timestamp: 1669303546
# (TunerInternal pid=363)   timesteps_since_restore: 0
# (TunerInternal pid=363)   training_iteration: 1
# (TunerInternal pid=363)   trial_id: 414eb_00002
# (TunerInternal pid=363)   warmup_time: 0.020821571350097656
# (TunerInternal pid=363)
# (TunerInternal pid=363) Result for objective_414eb_00003:
# (TunerInternal pid=363)   date: 2022-11-24_07-25-46
# (TunerInternal pid=363)   done: false
# (TunerInternal pid=363)   experiment_id: 2a92ed4aaf8a4ba38e5648576c78640e
# (TunerInternal pid=363)   hostname: raycluster-autoscaler-head-zkhfp
# (TunerInternal pid=363)   iterations_since_restore: 1
# (TunerInternal pid=363)   node_ip: 10.10.20.33
# (TunerInternal pid=363)   pid: 398
# (TunerInternal pid=363)   score: 4.0
# (TunerInternal pid=363)   time_since_restore: 0.00011372566223144531
# (TunerInternal pid=363)   time_this_iter_s: 0.00011372566223144531
# (TunerInternal pid=363)   time_total_s: 0.00011372566223144531
# (TunerInternal pid=363)   timestamp: 1669303546
# (TunerInternal pid=363)   timesteps_since_restore: 0
# (TunerInternal pid=363)   training_iteration: 1
# (TunerInternal pid=363)   trial_id: 414eb_00003
# (TunerInternal pid=363)   warmup_time: 0.020821571350097656
# (TunerInternal pid=363)
# (TunerInternal pid=363) Result for objective_414eb_00003:
# (TunerInternal pid=363)   date: 2022-11-24_07-25-46
# (TunerInternal pid=363)   done: true
# (TunerInternal pid=363)   experiment_id: 2a92ed4aaf8a4ba38e5648576c78640e
# (TunerInternal pid=363)   experiment_tag: 3_a=1.0000,b=3
# (TunerInternal pid=363)   hostname: raycluster-autoscaler-head-zkhfp
# (TunerInternal pid=363)   iterations_since_restore: 1
# (TunerInternal pid=363)   node_ip: 10.10.20.33
# (TunerInternal pid=363)   pid: 398
# (TunerInternal pid=363)   score: 4.0
# (TunerInternal pid=363)   time_since_restore: 0.00011372566223144531
# (TunerInternal pid=363)   time_this_iter_s: 0.00011372566223144531
# (TunerInternal pid=363)   time_total_s: 0.00011372566223144531
# (TunerInternal pid=363)   timestamp: 1669303546
# (TunerInternal pid=363)   timesteps_since_restore: 0
# (TunerInternal pid=363)   training_iteration: 1
# (TunerInternal pid=363)   trial_id: 414eb_00003
# (TunerInternal pid=363)   warmup_time: 0.020821571350097656
# (TunerInternal pid=363)
# (TunerInternal pid=363) == Status ==
# (TunerInternal pid=363) Current time: 2022-11-24 07:25:46 (running for 00:00:02.24)
# (TunerInternal pid=363) Memory usage on this node: 2.7/15.4 GiB
# (TunerInternal pid=363) Using FIFO scheduling algorithm.
# (TunerInternal pid=363) Resources requested: 0/5 CPUs, 0/0 GPUs, 0.0/16.76 GiB heap, 0.0/4.91 GiB objects
# (TunerInternal pid=363) Result logdir: /home/ray/ray_results/objective_2022-11-24_07-25-40
# (TunerInternal pid=363) Number of trials: 4/4 (4 TERMINATED)
# (TunerInternal pid=363) +-----------------------+------------+-----------------+-------+-----+--------+------------------+---------+
# (TunerInternal pid=363) | Trial name            | status     | loc             |     a |   b |   iter |   total time (s) |   score |
# (TunerInternal pid=363) |-----------------------+------------+-----------------+-------+-----+--------+------------------+---------|
# (TunerInternal pid=363) | objective_414eb_00000 | TERMINATED | 10.10.20.33:398 | 0.001 |   2 |      1 |      0.0001266   |  2      |
# (TunerInternal pid=363) | objective_414eb_00001 | TERMINATED | 10.10.20.33:398 | 0.01  |   3 |      1 |      9.08375e-05 |  3.0001 |
# (TunerInternal pid=363) | objective_414eb_00002 | TERMINATED | 10.10.20.33:398 | 0.1   |   1 |      1 |      7.29561e-05 |  1.01   |
# (TunerInternal pid=363) | objective_414eb_00003 | TERMINATED | 10.10.20.33:398 | 1     |   3 |      1 |      0.000113726 |  4      |
# (TunerInternal pid=363) +-----------------------+------------+-----------------+-------+-----+--------+------------------+---------+
# (TunerInternal pid=363)
# (TunerInternal pid=363)
# {'a': 0.1, 'b': 1}
# (TunerInternal pid=363) 2022-11-24 07:25:46,471	INFO tune.py:777 -- Total run time: 5.53 seconds (2.23 seconds for the tuning loop).
# (worker pid=138, ip=10.10.63.163) /tmp/ray/session_2022-11-24_07-21-18_572881_8/runtime_resources/working_dir_files/_ray_pkg_e69997be12e85035/ml/models/base/OptunaRay/brisk_bagging.py:17: DeprecationWarning: The module `ray.tune.suggest` has been moved to `ray.tune.search` and the old location will be deprecated soon. Please adjust your imports to point to the new location. Example: Do a global search and replace `ray.tune.suggest` with `ray.tune.search`.
# (worker pid=138, ip=10.10.63.163)   from ray.tune.suggest.optuna import OptunaSearch
# (worker pid=138, ip=10.10.63.163) 2022-11-24T07:25:52PST : INFO : font_manager : _load_fontmanager : 1633 : Message : generated new fontManager
# (worker pid=138, ip=10.10.63.163) /tmp/ray/session_2022-11-24_07-21-18_572881_8/runtime_resources/working_dir_files/_ray_pkg_e69997be12e85035/ml/models/base/OptunaRay/brisk_bagging.py:17: DeprecationWarning: The module `ray.tune.suggest.optuna` has been moved to `ray.tune.search.optuna` and the old location will be deprecated soon. Please adjust your imports to point to the new location. Example: Do a global search and replace `ray.tune.suggest.optuna` with `ray.tune.search.optuna`.
# (worker pid=138, ip=10.10.63.163)   from ray.tune.suggest.optuna import OptunaSearch
# (worker pid=138, ip=10.10.63.163) 2022-11-24T07:25:52PST : INFO : brisk_bagging : __discover_model__ : 86 : Message : brisk_xgb2: Starting training for trials:300, n_estimators  100
# (worker pid=138, ip=10.10.63.163) 2022-11-24 07:25:52,632	WARNING function_trainable.py:586 -- Function checkpointing is disabled. This may result in unexpected behavior when using checkpointing features or certain schedulers. To enable, set the train function arguments to be `func(config, checkpoint_dir=None)`.
# (worker pid=138, ip=10.10.63.163) [I 2022-11-24 07:25:52,635] A new study created in memory with name: optuna

# %%
from ray import tune
from ray.tune.search.bayesopt import BayesOptSearch

space = {
    'width': (0, 20),
    'height': (-100, 100),
}
bayesopt = BayesOptSearch(space, metric="mean_loss", mode="min")
tuner = tune.Tuner(
    objective,
    tune_config=tune.TuneConfig(
        search_alg=bayesopt,
    ),
)
tuner.fit()
# Out:
# (TunerInternal pid=482) 2022-11-24 07:27:52,092	WARNING function_trainable.py:586 -- Function checkpointing is disabled. This may result in unexpected behavior when using checkpointing features or certain schedulers. To enable, set the train function arguments to be `func(config, checkpoint_dir=None)`.
# (TunerInternal pid=482) == Status ==
# (TunerInternal pid=482) Current time: 2022-11-24 07:27:54 (running for 00:00:01.37)
# (TunerInternal pid=482) Memory usage on this node: 2.8/15.4 GiB
# (TunerInternal pid=482) Using FIFO scheduling algorithm.
# (TunerInternal pid=482) Resources requested: 1.0/5 CPUs, 0/0 GPUs, 0.0/16.76 GiB heap, 0.0/4.91 GiB objects
# (TunerInternal pid=482) Result logdir: /home/ray/ray_results/objective_2022-11-24_07-27-52
# (TunerInternal pid=482) Number of trials: 1/1 (1 RUNNING)
# (TunerInternal pid=482) +--------------------+----------+------------------+----------+---------+
# (TunerInternal pid=482) | Trial name         | status   | loc              |   height |   width |
# (TunerInternal pid=482) |--------------------+----------+------------------+----------+---------|
# (TunerInternal pid=482) | objective_901d919a | RUNNING  | 10.10.63.163:198 |  -25.092 | 19.0143 |
# (TunerInternal pid=482) +--------------------+----------+------------------+----------+---------+
# (TunerInternal pid=482)
# (TunerInternal pid=482)
# (TunerInternal pid=482) Result for objective_901d919a:
# (TunerInternal pid=482)   date: 2022-11-24_07-27-54
# (TunerInternal pid=482)   experiment_id: 1270e4eb0c0b4074a1e26ccf0fa93f81
# (TunerInternal pid=482)   hostname: raycluster-autoscaler-worker-small-group-dsm5q
# (TunerInternal pid=482)   node_ip: 10.10.63.163
# (TunerInternal pid=482)   pid: 198
# (TunerInternal pid=482)   timestamp: 1669303674
# (TunerInternal pid=482)   trial_id: 901d919a
# (TunerInternal pid=482)
# (TunerInternal pid=482) == Status ==
# (TunerInternal pid=482) Current time: 2022-11-24 07:27:54 (running for 00:00:01.38)
# (TunerInternal pid=482) Memory usage on this node: 2.8/15.4 GiB
# (TunerInternal pid=482) Using FIFO scheduling algorithm.
# (TunerInternal pid=482) Resources requested: 0/5 CPUs, 0/0 GPUs, 0.0/16.76 GiB heap, 0.0/4.91 GiB objects
# (TunerInternal pid=482) Result logdir: /home/ray/ray_results/objective_2022-11-24_07-27-52
# (TunerInternal pid=482) Number of trials: 1/1 (1 ERROR)
# (TunerInternal pid=482) +--------------------+----------+------------------+----------+---------+
# (TunerInternal pid=482) | Trial name         | status   | loc              |   height |   width |
# (TunerInternal pid=482) |--------------------+----------+------------------+----------+---------|
# (TunerInternal pid=482) | objective_901d919a | ERROR    | 10.10.63.163:198 |  -25.092 | 19.0143 |
# (TunerInternal pid=482) +--------------------+----------+------------------+----------+---------+
# (TunerInternal pid=482) Number of errored trials: 1
# (TunerInternal pid=482) +--------------------+--------------+--------------------------------------------------------------------------------------------------------------------------------------+
# (TunerInternal pid=482) | Trial name         |   # failures | error file                                                                                                                           |
# (TunerInternal pid=482) |--------------------+--------------+--------------------------------------------------------------------------------------------------------------------------------------|
# (TunerInternal pid=482) | objective_901d919a |            1 | /home/ray/ray_results/objective_2022-11-24_07-27-52/objective_901d919a_1_height=-25.0920,width=19.0143_2022-11-24_07-27-53/error.txt |
# (TunerInternal pid=482) +--------------------+--------------+--------------------------------------------------------------------------------------------------------------------------------------+
# (TunerInternal pid=482)
# (TunerInternal pid=482) 2022-11-24 07:27:54,535	ERROR trial_runner.py:993 -- Trial objective_901d919a: Error processing event.
# (TunerInternal pid=482) ray.exceptions.RayTaskError(KeyError): ray::ImplicitFunc.train() (pid=198, ip=10.10.63.163, repr=objective)
# (TunerInternal pid=482)   File "/home/ray/anaconda3/lib/python3.9/site-packages/ray/tune/trainable/trainable.py", line 355, in train
# (TunerInternal pid=482)     raise skipped from exception_cause(skipped)
# (TunerInternal pid=482)   File "/home/ray/anaconda3/lib/python3.9/site-packages/ray/tune/trainable/function_trainable.py", line 325, in entrypoint
# (TunerInternal pid=482)     return self._trainable_func(
# (TunerInternal pid=482)   File "/home/ray/anaconda3/lib/python3.9/site-packages/ray/tune/trainable/function_trainable.py", line 651, in _trainable_func
# (TunerInternal pid=482)     output = fn()
# (TunerInternal pid=482)   File "/tmp/ipykernel_20344/2397527074.py", line 5, in objective
# (TunerInternal pid=482) KeyError: 'a'
# (TunerInternal pid=482) 2022-11-24 07:27:54,643	ERROR tune.py:773 -- Trials did not complete: [objective_901d919a]
# (TunerInternal pid=482) 2022-11-24 07:27:54,643	INFO tune.py:777 -- Total run time: 2.55 seconds (1.38 seconds for the tuning loop).
