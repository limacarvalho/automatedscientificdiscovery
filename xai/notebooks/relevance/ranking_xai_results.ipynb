# %%
import pandas as pd

# %%
df_ranks = pd.read_csv('./covid_ray/df_scores_2.csv', sep=';')

# %%
df_ranks
# Out:
#                                     Unnamed: 0  brisk_xgb_shap  slug_xgb_shap  \
# 0                        new_cases_per_million        1.112261       0.164254
# 1                               population_cov        0.079029       0.025227
# 2                          life_expectancy_cov        0.000000       0.212764
# 3                                   Population        0.025751       0.054867
# 4                                     Area_km2        0.021997       0.034218
# 5                                  Density_km2        0.044032       0.025605
# 6                                       Year_x        0.000000       0.000000
# 7                                   Meningitis        0.030844       0.193961
# 8                                    Neoplasms        0.002839       0.021620
# 9               Fire, heat, and hot substances        0.038948       0.051923
# 10                                     Malaria        0.051040       0.066494
# ...

# %%
cols = df_ranks.columns[1:]

# %%
df_ranks[cols[0]]
# Out:
# 0     1.112261
# 1     0.079029
# 2     0.000000
# 3     0.025751
# 4     0.021997
# 5     0.044032
# 6     0.000000
# 7     0.030844
# 8     0.002839
# 9     0.038948
# 10    0.051040
# 11    0.000000
# 12    0.000000
# 13    0.026744
# 14    0.002295
# 15    0.020932
# 16    0.045088
# 17    0.000000
# 18    0.006717
# 19    0.000000
# 20    0.044940
# 21    0.006953
# 22    0.000000
# 23    0.000000
# 24    0.012946
# 25    0.031185
# 26    0.000000
# 27    0.070208
# 28    0.000000
# 29    0.033749
# 30    0.105243
# 31    0.000000
# 32    0.008425
# 33    0.060279
# 34    0.051755
# 35    0.000000
# 36    0.160245
# 37    0.003885
# 38    0.000000
# 39    0.070685
# Name: brisk_xgb_shap, dtype: float64
