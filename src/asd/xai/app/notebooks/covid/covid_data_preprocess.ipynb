# %%
# %load_ext autoreload
# %autoreload 2

# %%
import sys; sys.path.insert(0, '..') # add parent folder path where lib folder is

# %%
from utils import helper
import numpy as np
import pandas as pd

# %%
covid_file = '/mnt/c/Users/rwmas/GitHub/xai/xai_api/app/test/data/20220319_covid_merge.csv'
df = pd.read_csv(covid_file, sep=",")

df.head()
# Out:
#       location  new_cases_per_million  new_deaths_per_million  population_cov  \
# 0  Afghanistan               4171.944                 186.538      39835428.0
# 1      Albania              92109.327                1176.434       2872934.0
# 2      Algeria               5782.052                 148.940      44616626.0
# 3      Andorra             473136.492                1900.384         77354.0
# 4       Angola               2898.709                  55.799      33933611.0
#
#    life_expectancy_cov  Population  Area_km2  Density_km2  Year_x  Meningitis  \
# 0                64.83  37171921.0  252071.0         57.0  2019.0    0.004205
# 1                78.57   2882740.0   11100.0        100.0  2019.0    0.000451
# 2                76.88  42228408.0  919590.0         18.0  2019.0    0.000691
# 3                83.73     77006.0     181.0        165.0  2019.0    0.000000
# 4                61.15  30809787.0  481351.0         25.0  2019.0    0.008179
#
# ...

# %%
df['death_']
