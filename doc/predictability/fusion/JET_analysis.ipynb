# %%
import numpy as np
import pandas as pd
import ray

# %%
ray.init()

# %%
import asd

# %% [markdown]
# # The data

# %%
df = pd.read_csv("JET_(2036, 122)_DB3V13.csv")

# %%
df.head()
# Out:
#    TOK  TOK_ID     DIVNAME  LCUPDATE      DATE   SHOT       TIME  TIME_ID  \
# 0  JET       6  MarkGBSR    20031119  20020530  56145  62.647400    62647
# 1  JET       6  MarkGBSR    20031119  20020916  56603  64.882996    64883
# 2  JET       6  MarkGBSR    20031119  20020916  56605  64.882996    64883
# 3  JET       6  MarkGBSR    20031119  20020916  56606  64.882996    64883
# 4  JET       6  MarkGBSR    20031119  20020916  56610  65.379761    65380
#
#       T1     T2  ... IAEA92  DB2P5  DB2P8  DB3IS  DB3V5  IAE2000N  IAE2000X  \
# 0  62.56  62.75  ...      0      0      0      0      0         0         0
# 1  64.80  65.00  ...      0      0      0      0      0         0         0
# 2  64.80  65.00  ...      0      0      0      0      0         0         0
# 3  64.80  65.00  ...      0      0      0      0      0         0         0
# 4  65.25  65.50  ...      0      0      0      0      0         0         0
#
#    HMWS2003      SELDB3   SELDB3X
# 0         0  1111111010      1110
# 1         0  1111111111  11111100
# 2         0  1111111111  11111100
# 3         0  1111111111  11111100
# 4         0  1111111111  11111100
#
# [5 rows x 122 columns]

# %%
# columns we may use for a 4-1 fit
cols_4 = ["PLTH", "TAUTOT", "AMIN", "RGEO", "KAPPA", "KAPPAA",
          "KAREA", "VOL", "NEL", "PNBI", "PINJ",
          "WTH", "WTOT", "IP",
          "DELTA", "SEPLIM", "XPLIM", "AREA",
          ]

# %% [markdown]
# # Predictability Run

# %% [markdown]
# First check the number of combinations:

# %%
asd.get_column_combinations(all_cols=cols_4, inputs=4, outputs=1,targets=["PLTH", "TAUTOT"], amount_only=True)
# Out:
# 3640

# %% [markdown]
# This should be analysed in reasonable time when using ``method="kNN"``. However, feel free to further reduce ``cols_4``.

# %%
metrics_dict, datas_dict = asd.run_predictability(data=df,
                                                  input_cols=4,
                                                  output_cols=1,
                                                  col_set=cols_4,
                                                  primkey_cols = ["TOK"],
                                                  targets=["PLTH", "TAUTOT"],
                                                  method="kNN",
                                                  random_state_split=None,
                                                  refined_n_best=0
                                                  )

# %% [markdown]
# Let's have a look at the results:

# %%
metrics_df = pd.DataFrame.from_dict(metrics_dict).transpose().sort_values(by="kNN r2", ascending=False)

# %%
metrics_df.head(5)
# Out:
#                                 kNN r2  linear r2  pow. law r2   mean r2  \
# NEL  KAREA PNBI   AMIN  PLTH  0.960817   0.892848          NaN -0.001207
# AREA NEL   PNBI   KAPPA PLTH  0.960785   0.888489          NaN -0.000367
# VOL  NEL   SEPLIM PNBI  PLTH  0.955914   0.897683          NaN -0.006571
# AREA IP    PNBI   WTH   PLTH  0.955079   0.891353          NaN -0.000565
# VOL  NEL   PNBI   KAPPA PLTH  0.954949   0.879881          NaN -0.001392
#
#                                    kNN RMSE   linear RMSE  pow. law RMSE  \
# NEL  KAREA PNBI   AMIN  PLTH  918523.507544  1.518940e+06            NaN
# AREA NEL   PNBI   KAPPA PLTH  927024.033367  1.563225e+06            NaN
# VOL  NEL   SEPLIM PNBI  PLTH  960022.613494  1.462531e+06            NaN
# AREA IP    PNBI   WTH   PLTH  986172.762520  1.533682e+06            NaN
# VOL  NEL   PNBI   KAPPA PLTH  967828.434491  1.580343e+06            NaN
#
#                                  mean RMSE  kNN RMSE/std  linear RMSE/std  \
# NEL  KAREA PNBI   AMIN  PLTH  4.643039e+06      0.197947         0.327341
# AREA NEL   PNBI   KAPPA PLTH  4.682117e+06      0.198029         0.333933
# VOL  NEL   SEPLIM PNBI  PLTH  4.587253e+06      0.209967         0.319871
# AREA IP    PNBI   WTH   PLTH  4.654238e+06      0.211947         0.329617
# VOL  NEL   PNBI   KAPPA PLTH  4.562976e+06      0.212252         0.346581
#
#                               ...  pow. law MAPE  mean MAPE   kNN rae  \
# NEL  KAREA PNBI   AMIN  PLTH  ...            NaN   1.210217  0.164337
# AREA NEL   PNBI   KAPPA PLTH  ...            NaN   1.300888  0.158087
# VOL  NEL   SEPLIM PNBI  PLTH  ...            NaN   1.297672  0.169171
# AREA IP    PNBI   WTH   PLTH  ...            NaN   1.228608  0.159112
# VOL  NEL   PNBI   KAPPA PLTH  ...            NaN   1.211320  0.170784
#
#                               linear rae  pow. law rae  mean rae  kNN dcor  \
# NEL  KAREA PNBI   AMIN  PLTH    0.291313           NaN  1.003275  0.975373
# AREA NEL   PNBI   KAPPA PLTH    0.289579           NaN  1.001617  0.975281
# VOL  NEL   SEPLIM PNBI  PLTH    0.289345           NaN  1.007241  0.972935
# AREA IP    PNBI   WTH   PLTH    0.300718           NaN  0.999032  0.974066
# VOL  NEL   PNBI   KAPPA PLTH    0.306019           NaN  1.003358  0.973653
#
#                               linear dcor  pow. law dcor  mean dcor
# NEL  KAREA PNBI   AMIN  PLTH     0.943493            NaN   0.000000
# AREA NEL   PNBI   KAPPA PLTH     0.936923            NaN   0.000350
# VOL  NEL   SEPLIM PNBI  PLTH     0.944284            NaN   0.000000
# AREA IP    PNBI   WTH   PLTH     0.941806            NaN   0.001305
# VOL  NEL   PNBI   KAPPA PLTH     0.939394            NaN   0.000000
#
# [5 rows x 24 columns]

# %% [markdown]
# ## Refine predictability

# %% [markdown]
# First select the tuples that should be further analysed.

# %%
selected_tuples = asd.tuple_selection(metrics_dict, n_best=3 )

# %% [markdown]
# Then run the ``refine_predictability`` routine.

# %%
refined_metrics_dict, refined_datas_dict = asd.refine_predictability(best_tuples=selected_tuples,
                                                                     data_dict=datas_dict,
                                                                     time_left_for_this_task=60,
                                                                     n_jobs=-1,
                                                                     use_ray=True
                                                                     )

# %%
pd.DataFrame.from_dict(refined_metrics_dict).transpose()
# Out:
#                                     r2           RMSE      MAPE       rae  \
# NEL  KAREA PNBI   AMIN  PLTH  0.968342  825628.154668  0.117957  0.139893
# AREA NEL   PNBI   KAPPA PLTH  0.967612  842474.221484  0.143575  0.133107
# VOL  NEL   SEPLIM PNBI  PLTH  0.970533  784877.484422  0.125215  0.133270
#
#                                   dcor
# NEL  KAREA PNBI   AMIN  PLTH  0.980591
# AREA NEL   PNBI   KAPPA PLTH  0.980397
# VOL  NEL   SEPLIM PNBI  PLTH  0.982324

# %% [markdown]
# We may now compare the results:

# %%
for key in list(refined_metrics_dict.keys()):
    print(f'{key}: \t r2: {round(metrics_dict[key]["kNN r2"],2)}\t\t\t'
          f'RMSE: {round(metrics_dict[key]["kNN RMSE"],2)}\n '
          f'\t\t\t\t\t\t\t\t\t\t\t ref.: {round(refined_metrics_dict[key]["r2"],2)}\t\t\t'
          f'ref.: {round(refined_metrics_dict[key]["RMSE"],2)}\n')
# Out:
# ('NEL', 'KAREA', 'PNBI', 'AMIN', 'PLTH'): 	 r2: 0.96			RMSE: 918523.51
#  											 ref.: 0.97			ref.: 825628.15
#
# ('AREA', 'NEL', 'PNBI', 'KAPPA', 'PLTH'): 	 r2: 0.96			RMSE: 927024.03
#  											 ref.: 0.97			ref.: 842474.22
#
# ('VOL', 'NEL', 'SEPLIM', 'PNBI', 'PLTH'): 	 r2: 0.96			RMSE: 960022.61
#  											 ref.: 0.97			ref.: 784877.48

# %% [markdown]
# An improvement on the predictions can be obtained for ``time_left_for_this_task=60`` already.

# %% [markdown]
# # Plotting

# %%
asd.predictability_plot(refined_datas_dict,
                        list(refined_datas_dict.keys())[0],
                        refined_plot=True,
                        initial_datas_dict=datas_dict,
                        plot_along=["init",
                                    "linear",
                                    #"pl", # In this dataset and for 4-1 fits, there's in most cases some non-positive value
                                    #"mean"
                                    ]
                        )
# Out:
# <div>                            <div id="817ed905-5157-4b2d-8910-538fd9abb2dd" class="plotly-graph-div" style="height:555px; width:950px;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("817ed905-5157-4b2d-8910-538fd9abb2dd")) {                    Plotly.newPlot(                        "817ed905-5157-4b2d-8910-538fd9abb2dd",                        [{"mode":"markers","name":"init preds vs trues","opacity":0.8,"x":[8467000.0,5743000.0,15160000.0,2090000.0,1841000.0,6736000.0,3418000.0,3911000.0,11610000.0,11230000.0,765500.0,9072000.0,6477000.0,1689000.0,13269584.2225274,3848000.0,3371000.0,6260000.0,8858000.0,10080000.0,13005382.4861739,2286000.0,6479916.27066323,17850000.0,8702000.0,8962000.0,11230000.0,10000000.0,668500.0,11010000.0,1262000.0,12600000.0,11510000.0,12790000.0,10960000.0,2446000.0,13250000.0,12080000.0,10690000.0,2199000.0,14501457.4033557,10680000.0,4276000.0,7661000.0,3888000.0,12375688.6789013,704900.0,2349000.0,10070000.0,2180000.0,8949000.0,7433000.0,6431000.0,12340000.0,5178000.0,2864000.0,7486000.0,10530000.0,10180000.0,4250000.0,3263000.0,1434000.0,6217000.0,1298000.0,7421000.0,5474000.0,9781000.0,7807000.0,7394000.0,8205000.0,3739000.0,6098000.0,3392000.0,9864000.0,14310000.0,4016000.0,6040000.0,6840